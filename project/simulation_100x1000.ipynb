# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import SRW_v044 as SRW
from scipy.sparse import csr_matrix, csc_matrix, issparse
import functools

# %%
nsamples = 100
nnodes = 1000
edge_freq = 0.004
cliq_edge_freq = 0.114
hi_mut_freq = 0.5
hi_node = nnodes*3/4
group_labels = ['Subtype 1']*(nsamples//2) + ['Subtype 2']*(nsamples//2)
feature_names = ['Subnetwork 1', 'Subnetwork 2', 'High mut source', 'High mut target', 
                 'Random 1', 'Random 2', 
                 'Self loop', 'Intercept']
node_names = ['{}'.format(i) for i in range(1,nnodes+1)]
sample_names = ['{}'.format(i) for i in range(1,nsamples+1)]

rand_mut_freq = 0.015

# %%
rst_prob = 0.3
lam = 1e-1
WMW_b = 2e-4

# %%
def accuracy(activation_func, n_iter = 10):
    accuracy_history = []
    accuracy_val_history = []
    total_iter = n_iter
    for iter in range(n_iter):
        print("[%d/%d] iterations" %(iter+1, n_iter))
        degrees = [0]*nnodes
        edges = []
        features = [] #(11) cliq1, cliq2, hi_mut_source, hi_mut_target, rand1, rand2, rand3, rand4, rand5, self_loop, intercept
        for i in range(nnodes-1):
            for j in range(i+1,nnodes):
                if ((i<100 and j<100) and np.random.random()<cliq_edge_freq) or np.random.random()<edge_freq:
                    edges.append([i,j])
                    edges.append([j,i])
                    features.append([0,0,0,0,np.random.random(),np.random.random(),0,1])
                    features.append([0,0,0,0,np.random.random(),np.random.random(),0,1])
                    if (i<50 and j<50):
                        features[-2][0] = 1
                        features[-1][0] = 1
                    if (i>=50 and i<100 and j>=50 and j<100):
                        features[-2][1] = 1
                        features[-1][1] = 1
                    if i == nnodes-1:
                        features[-2][2] = 1
                        features[-1][3] = 1
                    if j == nnodes-1:
                        features[-2][3] = 1
                        features[-1][2] = 1
                    degrees[i] += 1
                    degrees[j] += 1

        for i in range(nnodes):
            edges.append([i,i])
            features.append([0,0,0,0,np.random.random(),np.random.random(),1,1])

        P_init = []
        for p in range(nsamples):
            p_init = []
            for i in range(nnodes):
                freq=0
                if p == i:
                    freq = 1
                elif i == hi_node:
                    freq = hi_mut_freq
                elif i<100:
                    if (max(p,i)<50 or min(p,i)>=50):
                        freq = 0.015
                    else:
                        freq = 0.000
                else:
                    freq = rand_mut_freq

                if np.random.random() < freq:
                    p_init.append(1)
                else:
                    p_init.append(0)

            P_init.append(p_init)

        edges = np.array(edges)
        features = csc_matrix(features)
        P_init = csr_matrix(P_init)


        SRW_obj = SRW.SRW_solver(edges, features, nnodes, P_init, rst_prob, group_labels, lam, w_init_sd=0.01, 
                                 w=None, feature_names=feature_names, sample_names=sample_names, 
                                 node_names=node_names, loss='WMW', norm_type='L1', learning_rate=0.5, 
                                 update_w_func='Adam', P_init_val=P_init, group_labels_val=group_labels, 
                                 ncpus=len(feature_names), maxit=100, early_stop=10, WMW_b=WMW_b, activation_func = activation_func)

        SRW_obj.train_SRW_GD()
    
        accuracy_history.append(SRW_obj.accuracy)
        accuracy_val_history.append(SRW_obj.accuracy_val)
    return accuracy_history, accuracy_val_history

# %%
accuracy_history_sigmoid, accuracy_val_history_sigmoid = accuracy('sigmoid', n_iter=10)

# %%
accuracy_history_tanh_relu, accuracy_val_history_tanh_relu = accuracy('tanh_relu', n_iter=10)

# %%
accuracy_history_softplus, accuracy_val_history_softplus = accuracy('softplus', n_iter=10)

# %%
accuracy_history_gaussian, accuracy_val_history_gaussian = accuracy('gaussian', n_iter=10)
# Out:
# [1/10] iterations
# finished calculating strength_grad: 22:53:22
# finished network propagation: 22:53:24
# finished calculating P_grad using pool: 22:53:26
# /content/SRW_v044.py:339: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, C), array(float64, 2d, A))
#   P_dot_PgradT[l,:,:] = np.dot(P, P_grad[l,:,:].T)
# /content/SRW_v044.py:340: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, C), array(float64, 2d, A))
#   P_dot_CgradT[l,:,:] = np.dot(P, C_grad[l,:,:].T)
# /content/SRW_v044.py:341: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, C), array(float64, 2d, A))
#   C_dot_PgradT[l,:,:] = np.dot(C, P_grad[l,:,:].T)
# /content/SRW_v044.py:342: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, C), array(float64, 2d, A))
#   C_dot_CgradT[l,:,:] = np.dot(C, C_grad[l,:,:].T)
# /usr/local/lib/python3.6/dist-packages/numba/ir_utils.py:2041: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'group2nsample_list' of function 'cost_func_and_grad_WMW'.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "SRW_v044.py", line 328:
# def cost_func_and_grad_WMW(nfeatures, nsamples, ngroups, P, P_grad, C, C_grad, sample2groupid_list,
#     <source elided>
#     P_dot_PT = np.dot(P, P.T) # m by m
#     P_dot_CT = np.dot(P, C.T) # m by g
#     ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# /usr/local/lib/python3.6/dist-packages/numba/ir_utils.py:2041: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'sample2groupid_list' of function 'cost_func_and_grad_WMW'.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "SRW_v044.py", line 328:
# def cost_func_and_grad_WMW(nfeatures, nsamples, ngroups, P, P_grad, C, C_grad, sample2groupid_list,
#     <source elided>
#     P_dot_PT = np.dot(P, P.T) # m by m
#     P_dot_CT = np.dot(P, C.T) # m by g
#     ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# finished calculating J and J_grad: 22:53:28
# /usr/local/lib/python3.6/dist-packages/numba/ir_utils.py:2041: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'sample2groupid_list' of function 'cost_func_WMW'.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "SRW_v044.py", line 384:
# def cost_func_WMW(nsamples, ngroups, P, C, sample2groupid_list, b=0.5):
#     <source elided>
#     C_dot_CT = np.dot(C, C.T) # g by g
#     cost = 0.
#     ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# *** 0 iteration: J is 48.42750622514336 cost_val is 10.011093452944202
# *** accuracy is 0.54 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:29
# finished network propagation: 22:53:29
# finished calculating P_grad using pool: 22:53:31
# finished calculating J and J_grad: 22:53:31
# *** 1 iteration: J is 48.79423585667978 cost_val is 11.54375006209378
# *** accuracy is 0.55 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:31
# finished network propagation: 22:53:32
# finished calculating P_grad using pool: 22:53:34
# finished calculating J and J_grad: 22:53:34
# *** 2 iteration: J is 45.57655735052738 cost_val is 9.991054368685893
# *** accuracy is 0.59 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:34
# finished network propagation: 22:53:35
# finished calculating P_grad using pool: 22:53:38
# finished calculating J and J_grad: 22:53:38
# *** 3 iteration: J is 38.00924192458348 cost_val is 5.102988620195747
# *** accuracy is 0.7 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:38
# finished network propagation: 22:53:38
# finished calculating P_grad using pool: 22:53:41
# finished calculating J and J_grad: 22:53:41
# *** 4 iteration: J is 26.92047338247098 cost_val is 4.1033832973521704
# *** accuracy is 0.82 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:41
# finished network propagation: 22:53:42
# finished calculating P_grad using pool: 22:53:45
# finished calculating J and J_grad: 22:53:45
# *** 5 iteration: J is 20.185507605395934 cost_val is 3.9360186212411783
# *** accuracy is 0.86 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:53:45
# finished network propagation: 22:53:45
# finished calculating P_grad using pool: 22:53:48
# finished calculating J and J_grad: 22:53:48
# *** 6 iteration: J is 18.279226915049307 cost_val is 3.9142134621656393
# *** accuracy is 0.87 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:53:48
# finished network propagation: 22:53:49
# finished calculating P_grad using pool: 22:53:51
# finished calculating J and J_grad: 22:53:51
# *** 7 iteration: J is 16.38318334076808 cost_val is 3.629936201566575
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:51
# finished network propagation: 22:53:52
# finished calculating P_grad using pool: 22:53:54
# finished calculating J and J_grad: 22:53:54
# *** 8 iteration: J is 14.315195501051209 cost_val is 3.1483547896176507
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:54
# finished network propagation: 22:53:55
# finished calculating P_grad using pool: 22:53:57
# finished calculating J and J_grad: 22:53:57
# *** 9 iteration: J is 13.309890562520618 cost_val is 2.726976991311718
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:53:57
# finished network propagation: 22:53:57
# finished calculating P_grad using pool: 22:54:00
# finished calculating J and J_grad: 22:54:00
# *** 10 iteration: J is 13.048119211549054 cost_val is 2.610799814346383
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:00
# finished network propagation: 22:54:01
# finished calculating P_grad using pool: 22:54:03
# finished calculating J and J_grad: 22:54:03
# *** 11 iteration: J is 13.425702144031892 cost_val is 2.7031299434152607
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:03
# finished network propagation: 22:54:04
# finished calculating P_grad using pool: 22:54:06
# finished calculating J and J_grad: 22:54:06
# *** 12 iteration: J is 13.865044065376193 cost_val is 2.7940053258435524
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:07
# finished network propagation: 22:54:07
# finished calculating P_grad using pool: 22:54:10
# finished calculating J and J_grad: 22:54:10
# *** 13 iteration: J is 14.190275742626774 cost_val is 2.8544695726981155
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:10
# finished network propagation: 22:54:11
# finished calculating P_grad using pool: 22:54:13
# finished calculating J and J_grad: 22:54:14
# *** 14 iteration: J is 14.312940489698022 cost_val is 2.87122559371845
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:14
# finished network propagation: 22:54:14
# finished calculating P_grad using pool: 22:54:17
# finished calculating J and J_grad: 22:54:17
# *** 15 iteration: J is 14.34445172331709 cost_val is 2.8674484764831014
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:18
# finished network propagation: 22:54:18
# finished calculating P_grad using pool: 22:54:21
# finished calculating J and J_grad: 22:54:21
# *** 16 iteration: J is 14.37550411876759 cost_val is 2.882662878556209
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:21
# finished network propagation: 22:54:22
# finished calculating P_grad using pool: 22:54:24
# finished calculating J and J_grad: 22:54:24
# *** 17 iteration: J is 14.424061678669672 cost_val is 2.923923767229818
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:25
# finished network propagation: 22:54:25
# finished calculating P_grad using pool: 22:54:28
# finished calculating J and J_grad: 22:54:28
# *** 18 iteration: J is 14.476824697648949 cost_val is 3.00164095412018
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:28
# finished network propagation: 22:54:29
# finished calculating P_grad using pool: 22:54:32
# finished calculating J and J_grad: 22:54:32
# *** 19 iteration: J is 14.522018313489113 cost_val is 3.097032247370299
# *** accuracy is 0.93 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:32
# finished network propagation: 22:54:33
# finished calculating P_grad using pool: 22:54:35
# finished calculating J and J_grad: 22:54:35
# *** 20 iteration: J is 14.501463810461528 cost_val is 3.1460466508607237
# *** accuracy is 0.92 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:36
# finished network propagation: 22:54:36
# finished calculating P_grad using pool: 22:54:39
# finished calculating J and J_grad: 22:54:39
# *** 21 iteration: J is 14.38534104476398 cost_val is 3.0993782024537153
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# [2/10] iterations
# finished calculating strength_grad: 22:54:40
# finished network propagation: 22:54:40
# finished calculating P_grad using pool: 22:54:41
# finished calculating J and J_grad: 22:54:42
# *** 0 iteration: J is 50.13801575528605 cost_val is 11.920805205724765
# *** accuracy is 0.49 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:42
# finished network propagation: 22:54:42
# finished calculating P_grad using pool: 22:54:45
# finished calculating J and J_grad: 22:54:45
# *** 1 iteration: J is 53.42686030213858 cost_val is 9.798286734603694
# *** accuracy is 0.46 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:45
# finished network propagation: 22:54:45
# finished calculating P_grad using pool: 22:54:47
# finished calculating J and J_grad: 22:54:47
# *** 2 iteration: J is 50.7662991388352 cost_val is 11.799647531253097
# *** accuracy is 0.47 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:48
# finished network propagation: 22:54:48
# finished calculating P_grad using pool: 22:54:50
# finished calculating J and J_grad: 22:54:50
# *** 3 iteration: J is 51.296148538143086 cost_val is 11.868386211573684
# *** accuracy is 0.46 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:50
# finished network propagation: 22:54:51
# finished calculating P_grad using pool: 22:54:53
# finished calculating J and J_grad: 22:54:53
# *** 4 iteration: J is 51.78988531847312 cost_val is 11.906038459047966
# *** accuracy is 0.45 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:54:53
# finished network propagation: 22:54:53
# finished calculating P_grad using pool: 22:54:56
# finished calculating J and J_grad: 22:54:56
# *** 5 iteration: J is 50.900971871388386 cost_val is 12.530999613724955
# *** accuracy is 0.48 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:56
# finished network propagation: 22:54:56
# finished calculating P_grad using pool: 22:54:58
# finished calculating J and J_grad: 22:54:58
# *** 6 iteration: J is 49.9156536120774 cost_val is 12.891883755974385
# *** accuracy is 0.51 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:54:58
# finished network propagation: 22:54:59
# finished calculating P_grad using pool: 22:55:01
# finished calculating J and J_grad: 22:55:01
# *** 7 iteration: J is 49.945203541851846 cost_val is 13.65533583054413
# *** accuracy is 0.52 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:55:01
# finished network propagation: 22:55:01
# finished calculating P_grad using pool: 22:55:03
# finished calculating J and J_grad: 22:55:03
# *** 8 iteration: J is 49.52837065196412 cost_val is 15.008148727473724
# *** accuracy is 0.53 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:55:03
# finished network propagation: 22:55:04
# finished calculating P_grad using pool: 22:55:06
# finished calculating J and J_grad: 22:55:06
# *** 9 iteration: J is 48.09193826574805 cost_val is 15.111503729076935
# *** accuracy is 0.58 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:55:06
# finished network propagation: 22:55:06
# finished calculating P_grad using pool: 22:55:09
# finished calculating J and J_grad: 22:55:09
# *** 10 iteration: J is 44.657546904070216 cost_val is 13.42671881435281
# *** accuracy is 0.63 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:09
# finished network propagation: 22:55:09
# finished calculating P_grad using pool: 22:55:12
# finished calculating J and J_grad: 22:55:12
# *** 11 iteration: J is 35.71407708653621 cost_val is 9.2349239434726
# *** accuracy is 0.73 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:12
# finished network propagation: 22:55:13
# finished calculating P_grad using pool: 22:55:15
# finished calculating J and J_grad: 22:55:15
# *** 12 iteration: J is 24.127345215364 cost_val is 5.627444135911025
# *** accuracy is 0.85 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:16
# finished network propagation: 22:55:16
# finished calculating P_grad using pool: 22:55:19
# finished calculating J and J_grad: 22:55:19
# *** 13 iteration: J is 18.95035188211288 cost_val is 4.559276409210664
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:55:20
# finished network propagation: 22:55:20
# finished calculating P_grad using pool: 22:55:23
# finished calculating J and J_grad: 22:55:23
# *** 14 iteration: J is 16.382521750637604 cost_val is 4.211264766444206
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:55:24
# finished network propagation: 22:55:24
# finished calculating P_grad using pool: 22:55:27
# finished calculating J and J_grad: 22:55:27
# *** 15 iteration: J is 14.581834609115644 cost_val is 3.8155143424247915
# *** accuracy is 0.92 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:55:28
# finished network propagation: 22:55:28
# finished calculating P_grad using pool: 22:55:31
# finished calculating J and J_grad: 22:55:31
# *** 16 iteration: J is 11.75780917347534 cost_val is 2.9582943788189846
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:31
# finished network propagation: 22:55:32
# finished calculating P_grad using pool: 22:55:35
# finished calculating J and J_grad: 22:55:35
# *** 17 iteration: J is 9.669124299073516 cost_val is 2.5832798907403385
# *** accuracy is 0.98 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:35
# finished network propagation: 22:55:35
# finished calculating P_grad using pool: 22:55:38
# finished calculating J and J_grad: 22:55:38
# *** 18 iteration: J is 8.756070409393512 cost_val is 2.551227494174565
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:39
# finished network propagation: 22:55:39
# finished calculating P_grad using pool: 22:55:42
# finished calculating J and J_grad: 22:55:42
# *** 19 iteration: J is 8.973942581910515 cost_val is 2.6991598518904074
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:43
# finished network propagation: 22:55:43
# finished calculating P_grad using pool: 22:55:46
# finished calculating J and J_grad: 22:55:46
# *** 20 iteration: J is 9.335846103315664 cost_val is 2.8334759783726313
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:46
# finished network propagation: 22:55:47
# finished calculating P_grad using pool: 22:55:49
# finished calculating J and J_grad: 22:55:50
# *** 21 iteration: J is 9.620202381221262 cost_val is 2.9462013488394496
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:50
# finished network propagation: 22:55:50
# finished calculating P_grad using pool: 22:55:53
# finished calculating J and J_grad: 22:55:53
# *** 22 iteration: J is 9.823369525069884 cost_val is 3.0104718268180357
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:53
# finished network propagation: 22:55:54
# finished calculating P_grad using pool: 22:55:57
# finished calculating J and J_grad: 22:55:57
# *** 23 iteration: J is 9.852667358515438 cost_val is 3.009941836956501
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:55:57
# finished network propagation: 22:55:57
# finished calculating P_grad using pool: 22:56:00
# finished calculating J and J_grad: 22:56:00
# *** 24 iteration: J is 9.735986857932524 cost_val is 2.9503195310329238
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:56:01
# finished network propagation: 22:56:01
# finished calculating P_grad using pool: 22:56:04
# finished calculating J and J_grad: 22:56:04
# *** 25 iteration: J is 9.638984185324777 cost_val is 2.8990643502902236
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:56:04
# finished network propagation: 22:56:04
# finished calculating P_grad using pool: 22:56:07
# finished calculating J and J_grad: 22:56:07
# *** 26 iteration: J is 9.904963918837243 cost_val is 2.9846646999227415
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:56:08
# finished network propagation: 22:56:08
# finished calculating P_grad using pool: 22:56:11
# finished calculating J and J_grad: 22:56:11
# *** 27 iteration: J is 10.884578974895351 cost_val is 3.3823628398557495
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:56:11
# finished network propagation: 22:56:12
# finished calculating P_grad using pool: 22:56:14
# finished calculating J and J_grad: 22:56:14
# *** 28 iteration: J is 12.298105330956155 cost_val is 3.9859247773627673
# *** accuracy is 0.98 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:56:15
# finished network propagation: 22:56:15
# finished calculating P_grad using pool: 22:56:18
# finished calculating J and J_grad: 22:56:18
# *** 29 iteration: J is 14.239467507851645 cost_val is 4.795592613585803
# *** accuracy is 0.97 accuracy_val is 1.0
#
#
# [3/10] iterations
# finished calculating strength_grad: 22:56:19
# finished network propagation: 22:56:19
# finished calculating P_grad using pool: 22:56:21
# finished calculating J and J_grad: 22:56:21
# *** 0 iteration: J is 48.51451173012033 cost_val is 11.301422242159074
# *** accuracy is 0.51 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:56:21
# finished network propagation: 22:56:21
# finished calculating P_grad using pool: 22:56:24
# finished calculating J and J_grad: 22:56:24
# *** 1 iteration: J is 50.487285432574964 cost_val is 11.041881020758936
# *** accuracy is 0.51 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:56:24
# finished network propagation: 22:56:24
# finished calculating P_grad using pool: 22:56:26
# finished calculating J and J_grad: 22:56:26
# *** 2 iteration: J is 48.36481996320656 cost_val is 13.65041767306517
# *** accuracy is 0.51 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:56:27
# finished network propagation: 22:56:27
# finished calculating P_grad using pool: 22:56:29
# finished calculating J and J_grad: 22:56:29
# *** 3 iteration: J is 49.192511842923096 cost_val is 14.866513811166078
# *** accuracy is 0.51 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 22:56:30
# finished network propagation: 22:56:30
# finished calculating P_grad using pool: 22:56:33
# finished calculating J and J_grad: 22:56:33
# *** 4 iteration: J is 48.52433377818342 cost_val is 14.258740345945624
# *** accuracy is 0.53 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 22:56:33
# finished network propagation: 22:56:34
# finished calculating P_grad using pool: 22:56:36
# finished calculating J and J_grad: 22:56:36
# *** 5 iteration: J is 46.97092535696362 cost_val is 13.092303729073288
# *** accuracy is 0.54 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 22:56:37
# finished network propagation: 22:56:37
# finished calculating P_grad using pool: 22:56:40
# finished calculating J and J_grad: 22:56:40
# *** 6 iteration: J is 42.01802007379314 cost_val is 10.686169469258443
# *** accuracy is 0.63 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 22:56:40
# finished network propagation: 22:56:41
# finished calculating P_grad using pool: 22:56:44
# finished calculating J and J_grad: 22:56:44
# *** 7 iteration: J is 31.824453310525804 cost_val is 7.192954805947147
# *** accuracy is 0.77 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 22:56:44
# finished network propagation: 22:56:45
# finished calculating P_grad using pool: 22:56:47
# finished calculating J and J_grad: 22:56:47
# *** 8 iteration: J is 20.671285443343947 cost_val is 4.535915717023289
# *** accuracy is 0.91 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 22:56:48
# finished network propagation: 22:56:48
# finished calculating P_grad using pool: 22:56:51
# finished calculating J and J_grad: 22:56:51
# *** 9 iteration: J is 15.805366118973847 cost_val is 3.4151609190387235
# *** accuracy is 0.94 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:56:51
# finished network propagation: 22:56:52
# finished calculating P_grad using pool: 22:56:54
# finished calculating J and J_grad: 22:56:54
# *** 10 iteration: J is 14.710060296398362 cost_val is 3.1450295774800705
# *** accuracy is 0.95 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:56:55
# finished network propagation: 22:56:55
# finished calculating P_grad using pool: 22:56:57
# finished calculating J and J_grad: 22:56:57
# *** 11 iteration: J is 14.296665049959538 cost_val is 3.0737382190336793
# *** accuracy is 0.96 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:56:58
# finished network propagation: 22:56:58
# finished calculating P_grad using pool: 22:57:00
# finished calculating J and J_grad: 22:57:00
# *** 12 iteration: J is 13.791597113289525 cost_val is 3.035479404532142
# *** accuracy is 0.95 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:01
# finished network propagation: 22:57:01
# finished calculating P_grad using pool: 22:57:04
# finished calculating J and J_grad: 22:57:04
# *** 13 iteration: J is 13.431799931173934 cost_val is 3.044645668295678
# *** accuracy is 0.96 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:04
# finished network propagation: 22:57:04
# finished calculating P_grad using pool: 22:57:07
# finished calculating J and J_grad: 22:57:07
# *** 14 iteration: J is 13.201375680977929 cost_val is 3.1082372633485624
# *** accuracy is 0.96 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:07
# finished network propagation: 22:57:07
# finished calculating P_grad using pool: 22:57:10
# finished calculating J and J_grad: 22:57:10
# *** 15 iteration: J is 13.088647637895145 cost_val is 2.9060771726677608
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:10
# finished network propagation: 22:57:11
# finished calculating P_grad using pool: 22:57:13
# finished calculating J and J_grad: 22:57:13
# *** 16 iteration: J is 13.226320349382583 cost_val is 2.6497337024261265
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:13
# finished network propagation: 22:57:14
# finished calculating P_grad using pool: 22:57:16
# finished calculating J and J_grad: 22:57:16
# *** 17 iteration: J is 13.463018170545668 cost_val is 2.4027245836009463
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:17
# finished network propagation: 22:57:17
# finished calculating P_grad using pool: 22:57:20
# finished calculating J and J_grad: 22:57:20
# *** 18 iteration: J is 13.577880364644516 cost_val is 2.428189562495299
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:20
# finished network propagation: 22:57:20
# finished calculating P_grad using pool: 22:57:23
# finished calculating J and J_grad: 22:57:23
# *** 19 iteration: J is 12.977063685304952 cost_val is 2.641674255700325
# *** accuracy is 0.95 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:23
# finished network propagation: 22:57:23
# finished calculating P_grad using pool: 22:57:26
# finished calculating J and J_grad: 22:57:26
# *** 20 iteration: J is 11.04373945798332 cost_val is 2.8621755008216376
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:26
# finished network propagation: 22:57:26
# finished calculating P_grad using pool: 22:57:29
# finished calculating J and J_grad: 22:57:29
# *** 21 iteration: J is 10.205849185566542 cost_val is 3.2563046927491492
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:29
# finished network propagation: 22:57:29
# finished calculating P_grad using pool: 22:57:31
# finished calculating J and J_grad: 22:57:31
# *** 22 iteration: J is 10.181002653437965 cost_val is 3.387820193963169
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:31
# finished network propagation: 22:57:32
# finished calculating P_grad using pool: 22:57:34
# finished calculating J and J_grad: 22:57:34
# *** 23 iteration: J is 10.233708390104354 cost_val is 3.4161690717092137
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:34
# finished network propagation: 22:57:34
# finished calculating P_grad using pool: 22:57:36
# finished calculating J and J_grad: 22:57:36
# *** 24 iteration: J is 10.251594817254148 cost_val is 3.4197140324151722
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:36
# finished network propagation: 22:57:37
# finished calculating P_grad using pool: 22:57:39
# finished calculating J and J_grad: 22:57:39
# *** 25 iteration: J is 10.235548145142362 cost_val is 3.410990340967605
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:39
# finished network propagation: 22:57:39
# finished calculating P_grad using pool: 22:57:41
# finished calculating J and J_grad: 22:57:41
# *** 26 iteration: J is 10.218557791670234 cost_val is 3.3838822153248516
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:41
# finished network propagation: 22:57:42
# finished calculating P_grad using pool: 22:57:44
# finished calculating J and J_grad: 22:57:44
# *** 27 iteration: J is 10.202622036372444 cost_val is 3.322602084919699
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:44
# finished network propagation: 22:57:44
# finished calculating P_grad using pool: 22:57:46
# finished calculating J and J_grad: 22:57:46
# *** 28 iteration: J is 10.255211123885449 cost_val is 3.218804947038598
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# [4/10] iterations
# finished calculating strength_grad: 22:57:47
# finished network propagation: 22:57:47
# finished calculating P_grad using pool: 22:57:49
# finished calculating J and J_grad: 22:57:49
# *** 0 iteration: J is 44.96056309993668 cost_val is 9.714267007393627
# *** accuracy is 0.58 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:49
# finished network propagation: 22:57:49
# finished calculating P_grad using pool: 22:57:52
# finished calculating J and J_grad: 22:57:52
# *** 1 iteration: J is 46.97473390353975 cost_val is 12.353272727769385
# *** accuracy is 0.58 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:52
# finished network propagation: 22:57:52
# finished calculating P_grad using pool: 22:57:54
# finished calculating J and J_grad: 22:57:54
# *** 2 iteration: J is 45.72079402752912 cost_val is 10.237744654011678
# *** accuracy is 0.57 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:55
# finished network propagation: 22:57:55
# finished calculating P_grad using pool: 22:57:57
# finished calculating J and J_grad: 22:57:57
# *** 3 iteration: J is 45.56274708320429 cost_val is 9.842259455302662
# *** accuracy is 0.58 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:57:57
# finished network propagation: 22:57:58
# finished calculating P_grad using pool: 22:58:00
# finished calculating J and J_grad: 22:58:00
# *** 4 iteration: J is 44.36358059116484 cost_val is 8.678469854145861
# *** accuracy is 0.59 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:00
# finished network propagation: 22:58:00
# finished calculating P_grad using pool: 22:58:03
# finished calculating J and J_grad: 22:58:03
# *** 5 iteration: J is 41.54289919799914 cost_val is 5.204550925711346
# *** accuracy is 0.64 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:03
# finished network propagation: 22:58:03
# finished calculating P_grad using pool: 22:58:06
# finished calculating J and J_grad: 22:58:06
# *** 6 iteration: J is 35.361937212186675 cost_val is 1.3925077314510155
# *** accuracy is 0.72 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:07
# finished network propagation: 22:58:07
# finished calculating P_grad using pool: 22:58:10
# finished calculating J and J_grad: 22:58:10
# *** 7 iteration: J is 28.198016305637665 cost_val is 0.2739639145853924
# *** accuracy is 0.78 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:11
# finished network propagation: 22:58:11
# finished calculating P_grad using pool: 22:58:14
# finished calculating J and J_grad: 22:58:14
# *** 8 iteration: J is 23.782881113592982 cost_val is 0.21128005627647192
# *** accuracy is 0.79 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:15
# finished network propagation: 22:58:15
# finished calculating P_grad using pool: 22:58:19
# finished calculating J and J_grad: 22:58:19
# *** 9 iteration: J is 22.248864734103638 cost_val is 0.1761019667450324
# *** accuracy is 0.81 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:19
# finished network propagation: 22:58:19
# finished calculating P_grad using pool: 22:58:23
# finished calculating J and J_grad: 22:58:23
# *** 10 iteration: J is 21.052553958723916 cost_val is 0.09248086376392355
# *** accuracy is 0.82 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:24
# finished network propagation: 22:58:24
# finished calculating P_grad using pool: 22:58:27
# finished calculating J and J_grad: 22:58:27
# *** 11 iteration: J is 20.291298387522414 cost_val is 0.05568312850158987
# *** accuracy is 0.82 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:28
# finished network propagation: 22:58:28
# finished calculating P_grad using pool: 22:58:31
# finished calculating J and J_grad: 22:58:31
# *** 12 iteration: J is 18.169324018955574 cost_val is 0.1275285521610856
# *** accuracy is 0.84 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:32
# finished network propagation: 22:58:32
# finished calculating P_grad using pool: 22:58:35
# finished calculating J and J_grad: 22:58:35
# *** 13 iteration: J is 16.310162336372077 cost_val is 0.2648018096208958
# *** accuracy is 0.86 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:36
# finished network propagation: 22:58:36
# finished calculating P_grad using pool: 22:58:39
# finished calculating J and J_grad: 22:58:39
# *** 14 iteration: J is 12.909436842653017 cost_val is 0.5641239651699386
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:40
# finished network propagation: 22:58:40
# finished calculating P_grad using pool: 22:58:43
# finished calculating J and J_grad: 22:58:43
# *** 15 iteration: J is 10.90648452260364 cost_val is 1.3180855757112493
# *** accuracy is 0.95 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:43
# finished network propagation: 22:58:44
# finished calculating P_grad using pool: 22:58:47
# finished calculating J and J_grad: 22:58:47
# *** 16 iteration: J is 9.597639273112039 cost_val is 2.076688516699756
# *** accuracy is 0.98 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:47
# finished network propagation: 22:58:47
# finished calculating P_grad using pool: 22:58:50
# finished calculating J and J_grad: 22:58:50
# *** 17 iteration: J is 9.685591453480987 cost_val is 2.590022386000112
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:51
# finished network propagation: 22:58:51
# finished calculating P_grad using pool: 22:58:54
# finished calculating J and J_grad: 22:58:54
# *** 18 iteration: J is 9.802660874684728 cost_val is 2.7786328879571878
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:54
# finished network propagation: 22:58:55
# finished calculating P_grad using pool: 22:58:57
# finished calculating J and J_grad: 22:58:57
# *** 19 iteration: J is 10.091331779400582 cost_val is 2.852495321045636
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:58:58
# finished network propagation: 22:58:58
# finished calculating P_grad using pool: 22:59:01
# finished calculating J and J_grad: 22:59:01
# *** 20 iteration: J is 10.393589543505078 cost_val is 2.6895110590247504
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:02
# finished network propagation: 22:59:02
# finished calculating P_grad using pool: 22:59:05
# finished calculating J and J_grad: 22:59:05
# *** 21 iteration: J is 10.892908603431819 cost_val is 2.628732003449947
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:05
# finished network propagation: 22:59:06
# finished calculating P_grad using pool: 22:59:09
# finished calculating J and J_grad: 22:59:09
# *** 22 iteration: J is 11.37896806596316 cost_val is 2.6711049112755942
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# [5/10] iterations
# finished calculating strength_grad: 22:59:10
# finished network propagation: 22:59:10
# finished calculating P_grad using pool: 22:59:12
# finished calculating J and J_grad: 22:59:12
# *** 0 iteration: J is 44.141953098345816 cost_val is 9.339975686083296
# *** accuracy is 0.64 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:12
# finished network propagation: 22:59:12
# finished calculating P_grad using pool: 22:59:14
# finished calculating J and J_grad: 22:59:14
# *** 1 iteration: J is 45.46875409091621 cost_val is 11.945207858186581
# *** accuracy is 0.61 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 22:59:15
# finished network propagation: 22:59:15
# finished calculating P_grad using pool: 22:59:17
# finished calculating J and J_grad: 22:59:17
# *** 2 iteration: J is 42.99481693472035 cost_val is 9.591722122652374
# *** accuracy is 0.67 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:18
# finished network propagation: 22:59:18
# finished calculating P_grad using pool: 22:59:21
# finished calculating J and J_grad: 22:59:21
# *** 3 iteration: J is 37.726091127975586 cost_val is 5.932285074783646
# *** accuracy is 0.71 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:21
# finished network propagation: 22:59:22
# finished calculating P_grad using pool: 22:59:25
# finished calculating J and J_grad: 22:59:25
# *** 4 iteration: J is 28.02133625030292 cost_val is 2.1083111135276558
# *** accuracy is 0.77 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:25
# finished network propagation: 22:59:26
# finished calculating P_grad using pool: 22:59:29
# finished calculating J and J_grad: 22:59:29
# *** 5 iteration: J is 19.149841694000113 cost_val is 1.6402456745580742
# *** accuracy is 0.89 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:29
# finished network propagation: 22:59:29
# finished calculating P_grad using pool: 22:59:32
# finished calculating J and J_grad: 22:59:32
# *** 6 iteration: J is 16.92610769129513 cost_val is 2.631190227171339
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:33
# finished network propagation: 22:59:33
# finished calculating P_grad using pool: 22:59:36
# finished calculating J and J_grad: 22:59:36
# *** 7 iteration: J is 16.067443658825887 cost_val is 3.1261059330100833
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:36
# finished network propagation: 22:59:36
# finished calculating P_grad using pool: 22:59:39
# finished calculating J and J_grad: 22:59:39
# *** 8 iteration: J is 15.651362687261013 cost_val is 3.2580515310720104
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:39
# finished network propagation: 22:59:40
# finished calculating P_grad using pool: 22:59:42
# finished calculating J and J_grad: 22:59:42
# *** 9 iteration: J is 15.185314757217412 cost_val is 3.20962005069253
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:43
# finished network propagation: 22:59:43
# finished calculating P_grad using pool: 22:59:46
# finished calculating J and J_grad: 22:59:46
# *** 10 iteration: J is 15.2182536992742 cost_val is 3.111988262125425
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:46
# finished network propagation: 22:59:46
# finished calculating P_grad using pool: 22:59:49
# finished calculating J and J_grad: 22:59:49
# *** 11 iteration: J is 15.85292034551994 cost_val is 3.1147255725363387
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:49
# finished network propagation: 22:59:50
# finished calculating P_grad using pool: 22:59:52
# finished calculating J and J_grad: 22:59:52
# *** 12 iteration: J is 15.93824143400184 cost_val is 3.1112352727763546
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:53
# finished network propagation: 22:59:53
# finished calculating P_grad using pool: 22:59:56
# finished calculating J and J_grad: 22:59:56
# *** 13 iteration: J is 15.479543264448356 cost_val is 3.0814104368031976
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:56
# finished network propagation: 22:59:56
# finished calculating P_grad using pool: 22:59:59
# finished calculating J and J_grad: 22:59:59
# *** 14 iteration: J is 14.728654589188606 cost_val is 3.221649739597087
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 22:59:59
# finished network propagation: 23:00:00
# finished calculating P_grad using pool: 23:00:02
# finished calculating J and J_grad: 23:00:02
# *** 15 iteration: J is 13.43678883017756 cost_val is 3.6174314124693296
# *** accuracy is 0.97 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:00:02
# finished network propagation: 23:00:02
# finished calculating P_grad using pool: 23:00:05
# finished calculating J and J_grad: 23:00:05
# *** 16 iteration: J is 11.850659317213863 cost_val is 3.608366042525679
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# [6/10] iterations
# finished calculating strength_grad: 23:00:05
# finished network propagation: 23:00:06
# finished calculating P_grad using pool: 23:00:07
# finished calculating J and J_grad: 23:00:07
# *** 0 iteration: J is 48.78547541851762 cost_val is 11.317134600677518
# *** accuracy is 0.56 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:07
# finished network propagation: 23:00:08
# finished calculating P_grad using pool: 23:00:10
# finished calculating J and J_grad: 23:00:10
# *** 1 iteration: J is 49.669017125110955 cost_val is 12.276674795513271
# *** accuracy is 0.54 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:10
# finished network propagation: 23:00:11
# finished calculating P_grad using pool: 23:00:13
# finished calculating J and J_grad: 23:00:13
# *** 2 iteration: J is 49.33949057643858 cost_val is 9.700549865388238
# *** accuracy is 0.57 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:13
# finished network propagation: 23:00:14
# finished calculating P_grad using pool: 23:00:16
# finished calculating J and J_grad: 23:00:16
# *** 3 iteration: J is 48.90302283765967 cost_val is 8.480903306594893
# *** accuracy is 0.57 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:17
# finished network propagation: 23:00:17
# finished calculating P_grad using pool: 23:00:20
# finished calculating J and J_grad: 23:00:20
# *** 4 iteration: J is 46.434160818777706 cost_val is 5.826686661521962
# *** accuracy is 0.56 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:20
# finished network propagation: 23:00:20
# finished calculating P_grad using pool: 23:00:23
# finished calculating J and J_grad: 23:00:23
# *** 5 iteration: J is 40.988368416246026 cost_val is 2.5529587793954134
# *** accuracy is 0.63 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:24
# finished network propagation: 23:00:24
# finished calculating P_grad using pool: 23:00:27
# finished calculating J and J_grad: 23:00:27
# *** 6 iteration: J is 34.3122235532975 cost_val is 1.281212598397511
# *** accuracy is 0.66 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:27
# finished network propagation: 23:00:28
# finished calculating P_grad using pool: 23:00:31
# finished calculating J and J_grad: 23:00:31
# *** 7 iteration: J is 29.352095471385184 cost_val is 1.1814585194469107
# *** accuracy is 0.77 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:31
# finished network propagation: 23:00:31
# finished calculating P_grad using pool: 23:00:34
# finished calculating J and J_grad: 23:00:34
# *** 8 iteration: J is 27.108514232762513 cost_val is 1.451514747643509
# *** accuracy is 0.8 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:34
# finished network propagation: 23:00:35
# finished calculating P_grad using pool: 23:00:37
# finished calculating J and J_grad: 23:00:37
# *** 9 iteration: J is 23.771098187514465 cost_val is 1.6113839059267094
# *** accuracy is 0.83 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:38
# finished network propagation: 23:00:38
# finished calculating P_grad using pool: 23:00:41
# finished calculating J and J_grad: 23:00:41
# *** 10 iteration: J is 21.75094260671337 cost_val is 1.758435715910273
# *** accuracy is 0.85 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:00:41
# finished network propagation: 23:00:42
# finished calculating P_grad using pool: 23:00:44
# finished calculating J and J_grad: 23:00:44
# *** 11 iteration: J is 18.710612288055913 cost_val is 3.2191132015751536
# *** accuracy is 0.9 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:00:45
# finished network propagation: 23:00:45
# finished calculating P_grad using pool: 23:00:48
# finished calculating J and J_grad: 23:00:48
# *** 12 iteration: J is 13.335827677664957 cost_val is 3.6164403012270143
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:00:48
# finished network propagation: 23:00:49
# finished calculating P_grad using pool: 23:00:51
# finished calculating J and J_grad: 23:00:51
# *** 13 iteration: J is 10.858041303819112 cost_val is 3.3560438123182403
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:00:52
# finished network propagation: 23:00:52
# finished calculating P_grad using pool: 23:00:55
# finished calculating J and J_grad: 23:00:55
# *** 14 iteration: J is 9.294648032830251 cost_val is 2.806226332123136
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:00:55
# finished network propagation: 23:00:56
# finished calculating P_grad using pool: 23:00:58
# finished calculating J and J_grad: 23:00:58
# *** 15 iteration: J is 8.988203211668226 cost_val is 2.5992486300104276
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:00:59
# finished network propagation: 23:00:59
# finished calculating P_grad using pool: 23:01:02
# finished calculating J and J_grad: 23:01:02
# *** 16 iteration: J is 11.108366456803871 cost_val is 3.3109307868409728
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:01:02
# finished network propagation: 23:01:03
# finished calculating P_grad using pool: 23:01:05
# finished calculating J and J_grad: 23:01:05
# *** 17 iteration: J is 19.96099187215169 cost_val is 7.0981437274222206
# *** accuracy is 0.95 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:01:06
# finished network propagation: 23:01:06
# finished calculating P_grad using pool: 23:01:09
# finished calculating J and J_grad: 23:01:09
# *** 18 iteration: J is 33.71474896789906 cost_val is 13.340879862401405
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# [7/10] iterations
# finished calculating strength_grad: 23:01:09
# finished network propagation: 23:01:10
# finished calculating P_grad using pool: 23:01:11
# finished calculating J and J_grad: 23:01:11
# *** 0 iteration: J is 46.15847848797283 cost_val is 10.245075342175442
# *** accuracy is 0.59 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:01:11
# finished network propagation: 23:01:12
# finished calculating P_grad using pool: 23:01:14
# finished calculating J and J_grad: 23:01:14
# *** 1 iteration: J is 48.70689483850825 cost_val is 10.024541057345552
# *** accuracy is 0.56 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:01:14
# finished network propagation: 23:01:15
# finished calculating P_grad using pool: 23:01:17
# finished calculating J and J_grad: 23:01:17
# *** 2 iteration: J is 45.82932428730029 cost_val is 11.83849566337447
# *** accuracy is 0.61 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:01:17
# finished network propagation: 23:01:17
# finished calculating P_grad using pool: 23:01:20
# finished calculating J and J_grad: 23:01:20
# *** 3 iteration: J is 45.32704424761328 cost_val is 12.855859660578128
# *** accuracy is 0.6 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:20
# finished network propagation: 23:01:20
# finished calculating P_grad using pool: 23:01:23
# finished calculating J and J_grad: 23:01:23
# *** 4 iteration: J is 44.040262912820225 cost_val is 11.23206593552208
# *** accuracy is 0.6 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:01:24
# finished network propagation: 23:01:24
# finished calculating P_grad using pool: 23:01:27
# finished calculating J and J_grad: 23:01:27
# *** 5 iteration: J is 40.62894867101629 cost_val is 8.481737429522521
# *** accuracy is 0.62 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:01:27
# finished network propagation: 23:01:28
# finished calculating P_grad using pool: 23:01:31
# finished calculating J and J_grad: 23:01:31
# *** 6 iteration: J is 31.687134781918214 cost_val is 5.327342545749369
# *** accuracy is 0.74 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:31
# finished network propagation: 23:01:32
# finished calculating P_grad using pool: 23:01:35
# finished calculating J and J_grad: 23:01:35
# *** 7 iteration: J is 19.83335679187799 cost_val is 3.9127692297330867
# *** accuracy is 0.85 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:35
# finished network propagation: 23:01:36
# finished calculating P_grad using pool: 23:01:39
# finished calculating J and J_grad: 23:01:39
# *** 8 iteration: J is 14.99661664840211 cost_val is 3.611806024117068
# *** accuracy is 0.88 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:39
# finished network propagation: 23:01:39
# finished calculating P_grad using pool: 23:01:42
# finished calculating J and J_grad: 23:01:42
# *** 9 iteration: J is 13.343218195083045 cost_val is 3.789959258687093
# *** accuracy is 0.9 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:43
# finished network propagation: 23:01:43
# finished calculating P_grad using pool: 23:01:46
# finished calculating J and J_grad: 23:01:46
# *** 10 iteration: J is 12.244516619557361 cost_val is 3.776725986174388
# *** accuracy is 0.93 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:47
# finished network propagation: 23:01:47
# finished calculating P_grad using pool: 23:01:50
# finished calculating J and J_grad: 23:01:50
# *** 11 iteration: J is 11.21823557569657 cost_val is 3.6735746265703857
# *** accuracy is 0.93 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:50
# finished network propagation: 23:01:51
# finished calculating P_grad using pool: 23:01:53
# finished calculating J and J_grad: 23:01:53
# *** 12 iteration: J is 9.871172846683825 cost_val is 3.426175500308023
# *** accuracy is 0.97 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:01:53
# finished network propagation: 23:01:54
# finished calculating P_grad using pool: 23:01:56
# finished calculating J and J_grad: 23:01:56
# *** 13 iteration: J is 8.950689831447688 cost_val is 2.946411229242155
# *** accuracy is 0.97 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:01:56
# finished network propagation: 23:01:57
# ...
# finished calculating P_grad using pool: 23:03:07
# finished calculating J and J_grad: 23:03:07
# *** 5 iteration: J is 35.262394434297626 cost_val is 3.3418742710694054
# *** accuracy is 0.71 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:07
# finished network propagation: 23:03:08
# finished calculating P_grad using pool: 23:03:11
# finished calculating J and J_grad: 23:03:11
# *** 6 iteration: J is 26.647653719882335 cost_val is 2.3581033880439684
# *** accuracy is 0.78 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:11
# finished network propagation: 23:03:12
# finished calculating P_grad using pool: 23:03:14
# finished calculating J and J_grad: 23:03:14
# *** 7 iteration: J is 19.21946591163973 cost_val is 1.9206565579643669
# *** accuracy is 0.88 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:03:15
# finished network propagation: 23:03:15
# finished calculating P_grad using pool: 23:03:18
# finished calculating J and J_grad: 23:03:18
# *** 8 iteration: J is 15.74973602729525 cost_val is 2.1537712301070773
# *** accuracy is 0.9 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:18
# finished network propagation: 23:03:19
# finished calculating P_grad using pool: 23:03:21
# finished calculating J and J_grad: 23:03:22
# *** 9 iteration: J is 15.96906650841198 cost_val is 2.561402071918908
# *** accuracy is 0.88 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:22
# finished network propagation: 23:03:22
# finished calculating P_grad using pool: 23:03:25
# finished calculating J and J_grad: 23:03:25
# *** 10 iteration: J is 14.523041714304089 cost_val is 2.669209178747283
# *** accuracy is 0.92 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:26
# finished network propagation: 23:03:26
# finished calculating P_grad using pool: 23:03:29
# finished calculating J and J_grad: 23:03:29
# *** 11 iteration: J is 12.759762797985102 cost_val is 3.093613727266836
# *** accuracy is 0.94 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:29
# finished network propagation: 23:03:29
# finished calculating P_grad using pool: 23:03:32
# finished calculating J and J_grad: 23:03:32
# *** 12 iteration: J is 10.908121073476096 cost_val is 3.2125991676404864
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:33
# finished network propagation: 23:03:33
# finished calculating P_grad using pool: 23:03:36
# finished calculating J and J_grad: 23:03:36
# *** 13 iteration: J is 10.976397556782734 cost_val is 3.6018997420091634
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:37
# finished network propagation: 23:03:37
# finished calculating P_grad using pool: 23:03:39
# finished calculating J and J_grad: 23:03:39
# *** 14 iteration: J is 10.691393240835893 cost_val is 3.5171747362936245
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:40
# finished network propagation: 23:03:40
# finished calculating P_grad using pool: 23:03:42
# finished calculating J and J_grad: 23:03:42
# *** 15 iteration: J is 10.195476029010832 cost_val is 3.2921184965266894
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:43
# finished network propagation: 23:03:43
# finished calculating P_grad using pool: 23:03:45
# finished calculating J and J_grad: 23:03:45
# *** 16 iteration: J is 9.801792875230653 cost_val is 3.1050632771451054
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:46
# finished network propagation: 23:03:46
# finished calculating P_grad using pool: 23:03:49
# finished calculating J and J_grad: 23:03:49
# *** 17 iteration: J is 9.520927486212077 cost_val is 2.964473805078464
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:03:49
# finished network propagation: 23:03:49
# finished calculating P_grad using pool: 23:03:52
# finished calculating J and J_grad: 23:03:52
# *** 18 iteration: J is 10.113018530416667 cost_val is 3.210951025379321
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# [9/10] iterations
# finished calculating strength_grad: 23:03:53
# finished network propagation: 23:03:53
# finished calculating P_grad using pool: 23:03:55
# finished calculating J and J_grad: 23:03:55
# *** 0 iteration: J is 45.53822837422702 cost_val is 10.08652474101762
# *** accuracy is 0.58 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:03:55
# finished network propagation: 23:03:55
# finished calculating P_grad using pool: 23:03:57
# finished calculating J and J_grad: 23:03:57
# *** 1 iteration: J is 47.47317767939776 cost_val is 9.857927916265371
# *** accuracy is 0.53 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:03:58
# finished network propagation: 23:03:58
# finished calculating P_grad using pool: 23:04:00
# finished calculating J and J_grad: 23:04:00
# *** 2 iteration: J is 45.45443923686914 cost_val is 12.181437103248413
# *** accuracy is 0.6 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:00
# finished network propagation: 23:04:01
# finished calculating P_grad using pool: 23:04:03
# finished calculating J and J_grad: 23:04:03
# *** 3 iteration: J is 45.69310906922573 cost_val is 12.376819931322016
# *** accuracy is 0.58 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:04
# finished network propagation: 23:04:04
# finished calculating P_grad using pool: 23:04:07
# finished calculating J and J_grad: 23:04:07
# *** 4 iteration: J is 44.26581946044118 cost_val is 10.129556562555857
# *** accuracy is 0.57 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:04:07
# finished network propagation: 23:04:07
# finished calculating P_grad using pool: 23:04:11
# finished calculating J and J_grad: 23:04:11
# *** 5 iteration: J is 41.35172473440752 cost_val is 6.943248121651494
# *** accuracy is 0.61 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:11
# finished network propagation: 23:04:11
# finished calculating P_grad using pool: 23:04:15
# finished calculating J and J_grad: 23:04:15
# *** 6 iteration: J is 36.36739178069649 cost_val is 4.000993376647333
# *** accuracy is 0.65 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:15
# finished network propagation: 23:04:15
# finished calculating P_grad using pool: 23:04:18
# finished calculating J and J_grad: 23:04:18
# *** 7 iteration: J is 27.24544321680839 cost_val is 2.0642777050191645
# *** accuracy is 0.81 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:19
# finished network propagation: 23:04:19
# finished calculating P_grad using pool: 23:04:22
# finished calculating J and J_grad: 23:04:22
# *** 8 iteration: J is 20.260055503470902 cost_val is 1.031367509620204
# *** accuracy is 0.85 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:23
# finished network propagation: 23:04:23
# finished calculating P_grad using pool: 23:04:26
# finished calculating J and J_grad: 23:04:26
# *** 9 iteration: J is 16.241410189857575 cost_val is 0.787564664546525
# *** accuracy is 0.87 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:26
# finished network propagation: 23:04:27
# finished calculating P_grad using pool: 23:04:30
# finished calculating J and J_grad: 23:04:30
# *** 10 iteration: J is 15.277359135112874 cost_val is 1.1263936351765131
# *** accuracy is 0.91 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:30
# finished network propagation: 23:04:30
# finished calculating P_grad using pool: 23:04:33
# finished calculating J and J_grad: 23:04:33
# *** 11 iteration: J is 15.425140212569609 cost_val is 1.7113735591572474
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:34
# finished network propagation: 23:04:34
# finished calculating P_grad using pool: 23:04:36
# finished calculating J and J_grad: 23:04:36
# *** 12 iteration: J is 14.174212299911675 cost_val is 2.2086562840259436
# *** accuracy is 0.91 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:04:37
# finished network propagation: 23:04:37
# finished calculating P_grad using pool: 23:04:40
# finished calculating J and J_grad: 23:04:40
# *** 13 iteration: J is 13.074112158109726 cost_val is 3.2903794154174744
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:40
# finished network propagation: 23:04:40
# finished calculating P_grad using pool: 23:04:43
# finished calculating J and J_grad: 23:04:43
# *** 14 iteration: J is 10.17567119031756 cost_val is 3.150472393764208
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:43
# finished network propagation: 23:04:43
# finished calculating P_grad using pool: 23:04:46
# finished calculating J and J_grad: 23:04:46
# *** 15 iteration: J is 9.690455504323722 cost_val is 3.0033444190528917
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:46
# finished network propagation: 23:04:47
# finished calculating P_grad using pool: 23:04:49
# finished calculating J and J_grad: 23:04:49
# *** 16 iteration: J is 9.327852123881131 cost_val is 2.844586868584523
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:49
# finished network propagation: 23:04:50
# finished calculating P_grad using pool: 23:04:52
# finished calculating J and J_grad: 23:04:52
# *** 17 iteration: J is 8.985172032837408 cost_val is 2.7019269608456646
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:53
# finished network propagation: 23:04:53
# finished calculating P_grad using pool: 23:04:56
# finished calculating J and J_grad: 23:04:56
# *** 18 iteration: J is 8.80438222294567 cost_val is 2.635691347433052
# *** accuracy is 1.0 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:04:56
# finished network propagation: 23:04:57
# finished calculating P_grad using pool: 23:04:59
# finished calculating J and J_grad: 23:04:59
# *** 19 iteration: J is 9.070407194114287 cost_val is 2.764095546089929
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:05:00
# finished network propagation: 23:05:00
# finished calculating P_grad using pool: 23:05:03
# finished calculating J and J_grad: 23:05:03
# *** 20 iteration: J is 9.211687617346229 cost_val is 2.7987839117965274
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# [10/10] iterations
# finished calculating strength_grad: 23:05:03
# finished network propagation: 23:05:04
# finished calculating P_grad using pool: 23:05:05
# finished calculating J and J_grad: 23:05:06
# *** 0 iteration: J is 44.6938481904487 cost_val is 10.426677611272057
# *** accuracy is 0.6 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:05:06
# finished network propagation: 23:05:06
# finished calculating P_grad using pool: 23:05:08
# finished calculating J and J_grad: 23:05:08
# *** 1 iteration: J is 46.284189038013245 cost_val is 12.076350549487765
# *** accuracy is 0.6 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:05:09
# finished network propagation: 23:05:09
# finished calculating P_grad using pool: 23:05:11
# finished calculating J and J_grad: 23:05:11
# *** 2 iteration: J is 44.791238129158636 cost_val is 10.289781930294101
# *** accuracy is 0.6 accuracy_val is 0.97
#
#
# finished calculating strength_grad: 23:05:11
# finished network propagation: 23:05:12
# finished calculating P_grad using pool: 23:05:14
# finished calculating J and J_grad: 23:05:14
# *** 3 iteration: J is 44.42309397630798 cost_val is 10.033589586964672
# *** accuracy is 0.63 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:05:15
# finished network propagation: 23:05:15
# finished calculating P_grad using pool: 23:05:18
# finished calculating J and J_grad: 23:05:18
# *** 4 iteration: J is 42.962174793487726 cost_val is 7.747406986820418
# *** accuracy is 0.62 accuracy_val is 0.97
#
#
# finished calculating strength_grad: 23:05:18
# finished network propagation: 23:05:19
# finished calculating P_grad using pool: 23:05:22
# finished calculating J and J_grad: 23:05:22
# *** 5 iteration: J is 39.41548127838725 cost_val is 5.005845033753634
# *** accuracy is 0.65 accuracy_val is 0.97
#
#
# finished calculating strength_grad: 23:05:22
# finished network propagation: 23:05:22
# finished calculating P_grad using pool: 23:05:26
# finished calculating J and J_grad: 23:05:26
# *** 6 iteration: J is 32.42968485040569 cost_val is 2.464012673557991
# *** accuracy is 0.71 accuracy_val is 0.98
#
#
# finished calculating strength_grad: 23:05:26
# finished network propagation: 23:05:26
# finished calculating P_grad using pool: 23:05:29
# finished calculating J and J_grad: 23:05:29
# *** 7 iteration: J is 25.904983075375004 cost_val is 1.2356451149291514
# *** accuracy is 0.77 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:05:30
# finished network propagation: 23:05:30
# finished calculating P_grad using pool: 23:05:33
# finished calculating J and J_grad: 23:05:33
# *** 8 iteration: J is 21.49716131288443 cost_val is 0.966794444176805
# *** accuracy is 0.83 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:05:34
# finished network propagation: 23:05:34
# finished calculating P_grad using pool: 23:05:37
# finished calculating J and J_grad: 23:05:37
# *** 9 iteration: J is 17.362501916364508 cost_val is 1.1067600311485302
# *** accuracy is 0.89 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:05:37
# finished network propagation: 23:05:38
# finished calculating P_grad using pool: 23:05:41
# finished calculating J and J_grad: 23:05:41
# *** 10 iteration: J is 16.69649460016638 cost_val is 1.6614223976166747
# *** accuracy is 0.88 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:05:41
# finished network propagation: 23:05:42
# finished calculating P_grad using pool: 23:05:44
# finished calculating J and J_grad: 23:05:45
# *** 11 iteration: J is 11.277762654823865 cost_val is 1.8949376111047065
# *** accuracy is 0.95 accuracy_val is 0.99
#
#
# finished calculating strength_grad: 23:05:45
# finished network propagation: 23:05:45
# finished calculating P_grad using pool: 23:05:48
# finished calculating J and J_grad: 23:05:48
# *** 12 iteration: J is 8.827605693272655 cost_val is 1.8619913622357795
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:05:48
# finished network propagation: 23:05:49
# finished calculating P_grad using pool: 23:05:51
# finished calculating J and J_grad: 23:05:51
# *** 13 iteration: J is 8.317986993097833 cost_val is 2.3116701435010207
# *** accuracy is 0.99 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:05:52
# finished network propagation: 23:05:52
# finished calculating P_grad using pool: 23:05:55
# finished calculating J and J_grad: 23:05:55
# *** 14 iteration: J is 8.8838967586111 cost_val is 2.708245379442346
# *** accuracy is 0.98 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:05:55
# finished network propagation: 23:05:56
# finished calculating P_grad using pool: 23:05:58
# finished calculating J and J_grad: 23:05:58
# *** 15 iteration: J is 10.232056011122836 cost_val is 3.2857229992144616
# *** accuracy is 0.96 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:05:59
# finished network propagation: 23:05:59
# finished calculating P_grad using pool: 23:06:02
# finished calculating J and J_grad: 23:06:02
# *** 16 iteration: J is 12.474296347865174 cost_val is 4.054474290752878
# *** accuracy is 0.96 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:06:03
# finished network propagation: 23:06:03
# finished calculating P_grad using pool: 23:06:06
# finished calculating J and J_grad: 23:06:06
# *** 17 iteration: J is 14.473805067974903 cost_val is 4.848957019189992
# *** accuracy is 0.95 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:06:06
# finished network propagation: 23:06:07
# finished calculating P_grad using pool: 23:06:09
# finished calculating J and J_grad: 23:06:09
# *** 18 iteration: J is 16.45735918311323 cost_val is 5.630206062283552
# *** accuracy is 0.93 accuracy_val is 1.0
#
#
# finished calculating strength_grad: 23:06:10
# finished network propagation: 23:06:10
# finished calculating P_grad using pool: 23:06:13
# finished calculating J and J_grad: 23:06:13
# *** 19 iteration: J is 18.515627329263832 cost_val is 6.4260451000757035
# *** accuracy is 0.94 accuracy_val is 1.0

# %%
print('[Sigmoid accuracy] mean:%.4f std:%.4f' %(np.mean(accuracy_history_sigmoid), np.std(accuracy_history_sigmoid)))
# Out:
# [Sigmoid accuracy] mean:0.9520 std:0.0236

# %%
print('[Tanh_relu accuracy] mean:%.4f std:%.4f' %(np.mean(accuracy_history_tanh_relu), np.std(accuracy_history_tanh_relu)))
# Out:
# [Tanh_relu accuracy] mean:0.6630 std:0.1134

# %%
print('[Softplus accuracy] mean:%.4f std:%.4f' %(np.mean(accuracy_history_softplus), np.std(accuracy_history_softplus)))
# Out:
# [Softplus accuracy] mean:0.9410 std:0.0130

# %%
print('[Gaussian accuracy] mean:%.4f std:%.4f' %(np.mean(accuracy_history_gaussian), np.std(accuracy_history_gaussian)))
# Out:
# [Gaussian accuracy] mean:0.9590 std:0.0453

# %%
degrees = [0]*nnodes
edges = []
features = [] #(11) cliq1, cliq2, hi_mut_source, hi_mut_target, rand1, rand2, rand3, rand4, rand5, self_loop, intercept
for i in range(nnodes-1):
    for j in range(i+1,nnodes):
        if ((i<100 and j<100) and np.random.random()<cliq_edge_freq) or np.random.random()<edge_freq:
            edges.append([i,j])
            edges.append([j,i])
            features.append([0,0,0,0,np.random.random(),np.random.random(),0,1])
            features.append([0,0,0,0,np.random.random(),np.random.random(),0,1])
            if (i<50 and j<50):
                features[-2][0] = 1
                features[-1][0] = 1
            if (i>=50 and i<100 and j>=50 and j<100):
                features[-2][1] = 1
                features[-1][1] = 1
            if i == nnodes-1:
                features[-2][2] = 1
                features[-1][3] = 1
            if j == nnodes-1:
                features[-2][3] = 1
                features[-1][2] = 1
            degrees[i] += 1
            degrees[j] += 1

for i in range(nnodes):
    edges.append([i,i])
    features.append([0,0,0,0,np.random.random(),np.random.random(),1,1])

P_init = []
for p in range(nsamples):
    p_init = []
    for i in range(nnodes):
        freq=0
        if p == i:
            freq = 1
        elif i == hi_node:
            freq = hi_mut_freq
        elif i<100:
            if (max(p,i)<50 or min(p,i)>=50):
                freq = 0.015
            else:
                freq = 0.000
        else:
            freq = rand_mut_freq

        if np.random.random() < freq:
            p_init.append(1)
        else:
            p_init.append(0)

    P_init.append(p_init)

edges = np.array(edges)
features = csc_matrix(features)
P_init = csr_matrix(P_init)


SRW_obj = SRW.SRW_solver(edges, features, nnodes, P_init, rst_prob, group_labels, lam, w_init_sd=0.01, 
                         w=None, feature_names=feature_names, sample_names=sample_names, 
                         node_names=node_names, loss='WMW', norm_type='L1', learning_rate=0.5, 
                         update_w_func='Adam', P_init_val=P_init, group_labels_val=group_labels, 
                         ncpus=len(feature_names), maxit=100, early_stop=10, WMW_b=WMW_b, activation_func = 'sigmoid')

SRW_obj.train_SRW_GD()

# %%
SRW_obj.w_map

# %%
import numpy as np
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SRW_obj.w = SRW_obj.w_list[0]
SRW_obj.map_w()
SRW_obj.w[-1] = 100
SRW_obj.w[-2] = -200
SRW_obj.Q = SRW.generate_Q(SRW_obj.edges, SRW_obj.nnodes, SRW_obj.features, SRW_obj.w)
P = SRW.iterative_PPR(SRW_obj.Q.toarray(), SRW.renorm(SRW_obj.P_init).toarray(), SRW_obj.rst_prob)
SRW_obj.C = SRW_obj.centroid(P, SRW_obj.ngroups, SRW_obj.group2indeces_list)
SRW_obj.calc_cost_and_acc_val()
SRW_obj.generate_Q_and_P_fin()

# %%
P_df = SRW_obj.P_fin_df.copy()
pca = PCA(n_components=2)
pca.fit(P_df.T)
# P_df_pca, pca_components, explained_variance_ratio = pyNBS.run_pca(P_df)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
for i in range(len(group_labels)):
    if group_labels[i] == 'Subtype 1':
        ax.plot(pca.components_[0,i], pca.components_[1,i], alpha=0.5, marker='o', color = 'r', linestyle='')
    else:
        ax.plot(pca.components_[0,i], pca.components_[1,i], alpha=0.5, marker='o', color = 'b', linestyle='')

plt.xlabel('Component 1')
plt.ylabel('Component 2')
ax.legend(loc='upper right')

plt.show()

# %%
SRW_obj.w = SRW_obj.w_list[-1]
SRW_obj.map_w()
SRW_obj.Q = SRW.generate_Q(SRW_obj.edges, SRW_obj.nnodes, SRW_obj.features, SRW_obj.w)
P = SRW.iterative_PPR(SRW_obj.Q.toarray(), SRW.renorm(SRW_obj.P_init).toarray(), SRW_obj.rst_prob)
SRW_obj.C = SRW_obj.centroid(P, SRW_obj.ngroups, SRW_obj.group2indeces_list)
SRW_obj.calc_cost_and_acc_val()
SRW_obj.generate_Q_and_P_fin()

P_df = SRW_obj.P_fin_df.copy()
pca = PCA(n_components=2)
pca.fit(P_df.T)

fig, ax = plt.subplots(figsize=(7, 7))
for i in range(len(group_labels)):
    if group_labels[i] == 'Subtype 1':
        ax.plot(pca.components_[0,i], pca.components_[1,i], alpha=0.5, marker='o', color = 'r', linestyle='')
    else:
        ax.plot(pca.components_[0,i], pca.components_[1,i], alpha=0.5, marker='o', color = 'b', linestyle='')

plt.xlabel('Component 1')
plt.ylabel('Component 2')
ax.legend(loc='upper right')

plt.show()

# %%
P_df

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(32,18))
ax = sns.heatmap(P_df.clip(upper=0.025),cmap='Reds', square=False)
# plt.savefig('data/sim1001000_P_df.pdf')
